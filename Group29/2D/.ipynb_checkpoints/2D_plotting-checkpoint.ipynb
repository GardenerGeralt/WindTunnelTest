# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('DATA/press_test.txt', header=0, sep='\t',  skipinitialspace = True)

# %%
data.head()
# Out:
#   Runnr Alpha-pr  Cd-press Cl-press Cm-press Cn-press   Ct-press  Re-press  \
# 0     /  degrees         /        /        /        /          /         /
# 1     1   -2.003  0.001752  -0.2165   0.0035  -0.2164  -0.005817  7.046E+5
# 2     2   -1.004  0.001411  -0.1191   0.0039  -0.1191  -0.000676  7.037E+5
# 3     3   -0.000  0.001280  -0.0171   0.0027  -0.0171   0.001280  7.034E+5
# 4     4    1.004  0.001838   0.0851   0.0014   0.0852   0.000347  7.032E+5
#
#   M-press  Q-press  ...   Cpl_017   Cpl_018   Cpl_019   Cpl_020   Cpl_021  \
# 0       /       Pa  ...  55.10000  60.10000  69.90000  75.00000  80.00000
# 1   0.127  1126.43  ...  -0.45317  -0.33675  -0.18723  -0.12405  -0.08466
# 2   0.127  1125.69  ...  -0.40842  -0.35962  -0.17088  -0.11066  -0.07496
# 3   0.127  1125.01  ...  -0.36723  -0.33329  -0.15124  -0.09681  -0.06443
# 4   0.127  1124.94  ...  -0.33017  -0.29442  -0.12963  -0.08000  -0.05258
#
#     Cpl_022    Cpl_023  Cn-p-cor   Ct-p-cor  Cm-p-cor
# 0  90.00000  100.00000         /          /         /
# 1   0.00047    0.17033   -0.2164  -0.005814    0.0035
# 2   0.00348    0.17304   -0.1191  -0.000674    0.0039
# 3   0.00672    0.17568   -0.0171   0.001282    0.0027
# 4   0.00952    0.17785    0.0852   0.000348    0.0014
#
# [5 rows x 62 columns]

# %%
dataT = data.T
dataT.columns = data['Alpha-pr'].values
dataT.drop(index=['Alpha-pr'], inplace=True)
dataT.head()
# Out:
#          degrees    -2.003    -1.004    -0.000     1.004     2.008     3.012  \
# Runnr          /         1         2         3         4         5         6
# Cd-press       /  0.001752  0.001411  0.001280  0.001838  0.002953  0.005009
# Cl-press       /   -0.2165   -0.1191   -0.0171    0.0851    0.1826    0.2770
# Cm-press       /    0.0035    0.0039    0.0027    0.0014    0.0019    0.0033
# Cn-press       /   -0.2164   -0.1191   -0.0171    0.0852    0.1826    0.2768
#
#              4.016     3.514     4.513  ...    16.007    16.511    17.011  \
# Runnr            7         8         9  ...        32        33        34
# Cd-press  0.007468  0.006232  0.008771  ...  0.224375  0.216425  0.222318
# Cl-press    0.3753    0.3261    0.4226  ...    0.5727    0.5062    0.5040
# Cm-press    0.0039    0.0035    0.0043  ...   -0.0673   -0.0562   -0.0559
# Cn-press    0.3749    0.3258    0.4219  ...    0.6123    0.5468    0.5470
#
#             16.516    16.018    15.516    15.016    14.520    14.024    13.542
# Runnr           35        36        37        38        39        40        41
# Cd-press  0.215566  0.232558  0.225085  0.223523  0.208144  0.193900  0.065654
# Cl-press    0.5023    0.6107    0.6256    0.6798    0.7337    0.7783    0.9270
# Cm-press   -0.0550   -0.0747   -0.0727   -0.0732   -0.0586   -0.0478    0.0289
# Cn-press    0.5429    0.6511    0.6630    0.7145    0.7625    0.8021    0.9166
#
# [5 rows x 42 columns]

# %%
dataT.loc[:,'degrees']
# Out:
# Runnr           /
# Cd-press        /
# Cl-press        /
# Cm-press        /
# Cn-press        /
#             ...
# Cpl_022      90.0
# Cpl_023     100.0
# Cn-p-cor        /
# Ct-p-cor        /
# Cm-p-cor        /
# Name: degrees, Length: 61, dtype: object

# %%
plt.scatter(x, y)
